# %% [markdown]
# ## **LING 571 - Final Exam : Programming Project**
# ### **Programming Project Topic : Sentiment Analysis on the NLTK Corpus of Movie Reviews**
# ### **Student Name: Bhagyashri Patil**

# %% [markdown]
# Importing NLTK:

# %%
import nltk
nltk.download('book', quiet=True)
from nltk.corpus import movie_reviews

# %% [markdown]
# Looking for words in the Movie Reviews corpus:

# %%
movie_reviews.words()
# Out:
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...]

# %% [markdown]
# Check the size of the Movie Reviews corpus:

# %%
len(movie_reviews.words())
# Out:
# 1583820

# %% [markdown]
# Looking for the Categories of Movie Reviews corpus which gives us the type of reviews:

# %%
movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %% [markdown]
# Calculating the Frequency Distribution of the words in the Movie Reviews corpus:

# %%
movie_reviews_freq = nltk.FreqDist(movie_reviews.words())
movie_reviews_freq.most_common(20)
# Out:
# [(',', 77717),
#  ('the', 76529),
#  ('.', 65876),
#  ('a', 38106),
#  ('and', 35576),
#  ('of', 34123),
#  ('to', 31937),
#  ("'", 30585),
#  ('is', 25195),
#  ('in', 21822),
#  ('s', 18513),
#  ('"', 17612),
#  ('it', 16107),
#  ('that', 15924),
#  ('-', 15595),
#  (')', 11781),
#  ('(', 11664),
#  ('as', 11378),
#  ('with', 10792),
#  ('for', 9961)]

# %% [markdown]
# Looking for count of Distinct words in the Movie Reviews corpus:

# %%
len(movie_reviews_freq)
# Out:
# 39768

# %% [markdown]
# Checking for the File IDs of the Movie Reviews corpus:

# %%
movie_reviews.fileids()
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt',
#  'neg/cv005_29357.txt',
#  'neg/cv006_17022.txt',
#  'neg/cv007_4992.txt',
#  'neg/cv008_29326.txt',
#  'neg/cv009_29417.txt',
#  'neg/cv010_29063.txt',
#  'neg/cv011_13044.txt',
#  'neg/cv012_29411.txt',
#  'neg/cv013_10494.txt',
#  'neg/cv014_15600.txt',
#  'neg/cv015_29356.txt',
#  'neg/cv016_4348.txt',
#  'neg/cv017_23487.txt',
#  'neg/cv018_21672.txt',
#  'neg/cv019_16117.txt',
#  'neg/cv020_9234.txt',
#  'neg/cv021_17313.txt',
#  'neg/cv022_14227.txt',
#  'neg/cv023_13847.txt',
#  'neg/cv024_7033.txt',
#  'neg/cv025_29825.txt',
#  'neg/cv026_29229.txt',
#  'neg/cv027_26270.txt',
#  'neg/cv028_26964.txt',
#  'neg/cv029_19943.txt',
#  'neg/cv030_22893.txt',
#  'neg/cv031_19540.txt',
#  'neg/cv032_23718.txt',
#  'neg/cv033_25680.txt',
#  'neg/cv034_29446.txt',
#  'neg/cv035_3343.txt',
#  'neg/cv036_18385.txt',
#  'neg/cv037_19798.txt',
# ...

# %% [markdown]
# Here, we can see the Fileids have the starting as 'neg' and 'pos'. So, this indicates that every file id is denoted by either positive or negative tag.

# %% [markdown]
# Looking for the Reviews with Positive tag:

# %%
movie_reviews.fileids('pos')
# Out:
# ['pos/cv000_29590.txt',
#  'pos/cv001_18431.txt',
#  'pos/cv002_15918.txt',
#  'pos/cv003_11664.txt',
#  'pos/cv004_11636.txt',
#  'pos/cv005_29443.txt',
#  'pos/cv006_15448.txt',
#  'pos/cv007_4968.txt',
#  'pos/cv008_29435.txt',
#  'pos/cv009_29592.txt',
#  'pos/cv010_29198.txt',
#  'pos/cv011_12166.txt',
#  'pos/cv012_29576.txt',
#  'pos/cv013_10159.txt',
#  'pos/cv014_13924.txt',
#  'pos/cv015_29439.txt',
#  'pos/cv016_4659.txt',
#  'pos/cv017_22464.txt',
#  'pos/cv018_20137.txt',
#  'pos/cv019_14482.txt',
#  'pos/cv020_8825.txt',
#  'pos/cv021_15838.txt',
#  'pos/cv022_12864.txt',
#  'pos/cv023_12672.txt',
#  'pos/cv024_6778.txt',
#  'pos/cv025_3108.txt',
#  'pos/cv026_29325.txt',
#  'pos/cv027_25219.txt',
#  'pos/cv028_26746.txt',
#  'pos/cv029_18643.txt',
#  'pos/cv030_21593.txt',
#  'pos/cv031_18452.txt',
#  'pos/cv032_22550.txt',
#  'pos/cv033_24444.txt',
#  'pos/cv034_29647.txt',
#  'pos/cv035_3954.txt',
#  'pos/cv036_16831.txt',
#  'pos/cv037_18510.txt',
# ...

# %% [markdown]
# Lets check for the words containing in this Positive tagged fileids:

# %%
movie_reviews.words('pos/cv000_29590.txt')
# Out:
# ['films', 'adapted', 'from', 'comic', 'books', 'have', ...]

# %% [markdown]
# Looking for the Reviews with Negative tag:

# %%
movie_reviews.fileids('neg')
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt',
#  'neg/cv005_29357.txt',
#  'neg/cv006_17022.txt',
#  'neg/cv007_4992.txt',
#  'neg/cv008_29326.txt',
#  'neg/cv009_29417.txt',
#  'neg/cv010_29063.txt',
#  'neg/cv011_13044.txt',
#  'neg/cv012_29411.txt',
#  'neg/cv013_10494.txt',
#  'neg/cv014_15600.txt',
#  'neg/cv015_29356.txt',
#  'neg/cv016_4348.txt',
#  'neg/cv017_23487.txt',
#  'neg/cv018_21672.txt',
#  'neg/cv019_16117.txt',
#  'neg/cv020_9234.txt',
#  'neg/cv021_17313.txt',
#  'neg/cv022_14227.txt',
#  'neg/cv023_13847.txt',
#  'neg/cv024_7033.txt',
#  'neg/cv025_29825.txt',
#  'neg/cv026_29229.txt',
#  'neg/cv027_26270.txt',
#  'neg/cv028_26964.txt',
#  'neg/cv029_19943.txt',
#  'neg/cv030_22893.txt',
#  'neg/cv031_19540.txt',
#  'neg/cv032_23718.txt',
#  'neg/cv033_25680.txt',
#  'neg/cv034_29446.txt',
#  'neg/cv035_3343.txt',
#  'neg/cv036_18385.txt',
#  'neg/cv037_19798.txt',
# ...

# %% [markdown]
# Lets check for the words containing in this Negative tagged fileids:

# %%
movie_reviews.words('neg/cv000_29416.txt')
# Out:
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...]

# %% [markdown]
# Creating master list of all the words contained in the frequency distribution of the Movie Reviews corpus:

# %%
movie_reviews_list = list(movie_reviews_freq)[:4000]
movie_reviews_list
# Out:
# ['plot',
#  ':',
#  'two',
#  'teen',
#  'couples',
#  'go',
#  'to',
#  'a',
#  'church',
#  'party',
#  ',',
#  'drink',
#  'and',
#  'then',
#  'drive',
#  '.',
#  'they',
#  'get',
#  'into',
#  'an',
#  'accident',
#  'one',
#  'of',
#  'the',
#  'guys',
#  'dies',
#  'but',
#  'his',
#  'girlfriend',
#  'continues',
#  'see',
#  'him',
#  'in',
#  'her',
#  'life',
#  'has',
#  'nightmares',
#  'what',
#  "'",
#  's',
#  'deal',
#  '?',
#  'watch',
#  'movie',
#  '"',
#  'sorta',
#  'find',
#  'out',
#  'critique',
#  'mind',
#  '-',
#  'fuck',
#  'for',
#  'generation',
#  'that',
#  'touches',
#  'on',
#  'very',
#  'cool',
#  'idea',
#  'presents',
#  'it',
#  'bad',
#  'package',
#  'which',
#  'is',
#  'makes',
#  'this',
#  'review',
#  'even',
#  'harder',
#  'write',
#  'since',
#  'i',
#  'generally',
#  'applaud',
#  'films',
#  'attempt',
#  'break',
#  'mold',
#  'mess',
#  'with',
#  'your',
#  'head',
#  'such',
#  '(',
#  'lost',
#  'highway',
#  '&',
# ...

# %% [markdown]
# First step for analyzing the Sentiments of Movie Reviews:

# %%
movie_reviews = {}

# %% [markdown]
# I have chosen a single movie, to pass for the sentiment analysis:

# %%
reviews = nltk.corpus.movie_reviews.words('neg/cv942_18509.txt')

# %% [markdown]
# If any word from 'movie_reviews_list' matches with the 'reviews' then we give output as TRUE, else FALSE.

# %%
for i in range(len(movie_reviews_list)):
  movie_reviews[movie_reviews_list[i]] = movie_reviews_list[i] in reviews

# %% [markdown]
# Looking for all words to whom we have alloted TRUE:

# %%
[i for i in movie_reviews_list if movie_reviews[i] == True]
# Out:
# ['plot',
#  ':',
#  'to',
#  'a',
#  ',',
#  'and',
#  'then',
#  '.',
#  'get',
#  'into',
#  'an',
#  'one',
#  'of',
#  'the',
#  'guys',
#  'but',
#  'his',
#  'see',
#  'him',
#  'in',
#  'her',
#  'life',
#  'what',
#  "'",
#  's',
#  '?',
#  '"',
#  'find',
#  'out',
#  '-',
#  'for',
#  'that',
#  'on',
#  'it',
#  'bad',
#  'which',
#  'is',
#  'this',
#  'review',
#  'even',
#  'i',
#  'mess',
#  'with',
#  '(',
#  ')',
#  'there',
#  'are',
#  'good',
#  'all',
#  'these',
#  'just',
#  'didn',
#  't',
#  'seem',
#  'have',
#  'its',
#  'problem',
#  'off',
#  'fantasy',
#  'world',
#  'you',
#  'as',
#  'no',
#  'back',
#  'from',
#  'who',
#  'like',
#  'scenes',
#  'not',
#  'don',
#  'film',
#  'when',
#  'does',
#  'me',
#  'over',
#  'up',
#  'after',
#  'got',
#  'completely',
#  'final',
#  'do',
#  'make',
#  'we',
#  'by',
#  'half',
#  'way',
#  'movies',
#  'before',
#  'given',
#  'running',
#  'away',
#  'about',
#  'throughout',
#  '!',
#  'down',
# ...

# %% [markdown]
# Here, we can observe the works such as 'insults', 'destroys', 'attacks' etc. which conclude that the sentiment of the file is Negative.

# %% [markdown]
# Creating a Document which comprises of the words and categories of the reviews:

# %%
movie_reviews_document = [ 
                          (nltk.corpus.movie_reviews.words(reviews_file_id), cat)
                          for reviews_file_id in nltk.corpus.movie_reviews.fileids()
                          for cat in nltk.corpus.movie_reviews.categories(reviews_file_id)
                          ]

# %% [markdown]
# Displaying Document contents:

# %%
movie_reviews_document
# Out:
# [(['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...], 'neg'),
#  (['the', 'happy', 'bastard', "'", 's', 'quick', 'movie', ...], 'neg'),
#  (['it', 'is', 'movies', 'like', 'these', 'that', 'make', ...], 'neg'),
#  (['"', 'quest', 'for', 'camelot', '"', 'is', 'warner', ...], 'neg'),
#  (['synopsis', ':', 'a', 'mentally', 'unstable', 'man', ...], 'neg'),
#  (['capsule', ':', 'in', '2176', 'on', 'the', 'planet', ...], 'neg'),
#  (['so', 'ask', 'yourself', 'what', '"', '8mm', '"', '(', ...], 'neg'),
#  (['that', "'", 's', 'exactly', 'how', 'long', 'the', ...], 'neg'),
#  (['call', 'it', 'a', 'road', 'trip', 'for', 'the', ...], 'neg'),
#  (['plot', ':', 'a', 'young', 'french', 'boy', 'sees', ...], 'neg'),
#  (['best', 'remembered', 'for', 'his', 'understated', ...], 'neg'),
#  (['janeane', 'garofalo', 'in', 'a', 'romantic', ...], 'neg'),
#  (['and', 'now', 'the', 'high', '-', 'flying', 'hong', ...], 'neg'),
#  (['a', 'movie', 'like', 'mortal', 'kombat', ':', ...], 'neg'),
# ...

# %% [markdown]
# Defining a function which searches the required TRUE/FALSE sentiments:

# %%
def search_sentiments(all_words):
  sentiment_function = {}
  for i in movie_reviews_list:
    sentiment_function[i] = i in all_words

  return sentiment_function

# %% [markdown]
# Displaying results for the function search_sentiments for the very first file in the document created:

# %%
search_sentiments(movie_reviews_document[1][0])
# Out:
# {'plot': False,
#  ':': False,
#  'two': False,
#  'teen': False,
#  'couples': False,
#  'go': False,
#  'to': True,
#  'a': True,
#  'church': False,
#  'party': False,
#  ',': True,
#  'drink': False,
#  'and': True,
#  'then': False,
#  'drive': False,
#  '.': True,
#  'they': True,
#  'get': True,
#  'into': True,
#  'an': False,
#  'accident': False,
#  'one': False,
#  'of': True,
#  'the': True,
#  'guys': False,
#  'dies': False,
#  'but': False,
#  'his': False,
#  'girlfriend': False,
#  'continues': False,
#  'see': False,
#  'him': False,
#  'in': True,
#  'her': True,
#  'life': False,
#  'has': True,
#  'nightmares': False,
#  'what': True,
#  "'": True,
#  's': True,
#  'deal': False,
#  '?': False,
#  'watch': False,
#  'movie': True,
#  '"': True,
#  'sorta': False,
#  'find': False,
#  'out': True,
#  'critique': False,
#  'mind': False,
#  '-': False,
#  'fuck': False,
#  'for': True,
#  'generation': False,
#  'that': True,
#  'touches': False,
#  'on': True,
# ...
